# %% [markdown]
# <a href="https://colab.research.google.com/github/SoonChuen/aml-project/blob/main/01_6b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="01-ai/Yi-6B")
# Out:
# config.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]

# %%
import accelerate  # Import accelerate before transformers
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load model directly
tokenizer = AutoTokenizer.from_pretrained("01-ai/Yi-6B")
model = AutoModelForCausalLM.from_pretrained("01-ai/Yi-6B")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
while True:
    # Prompt content
    prompt = input("Enter your prompt (or 'exit' to quit): ")

    # Check if the user wants to exit
    if prompt.lower() == 'exit':
        break

    # Tokenize the input prompt
    input_ids = tokenizer.encode(prompt, return_tensors="pt").to(device)

    # Generate text
    output_ids = model.generate(input_ids, max_length=80, num_beams=5, no_repeat_ngram_size=2)

    # Decode and print the generated text
    generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    print("Generated text:", generated_text)
# Out:
# Enter your prompt (or 'exit' to quit): hi
# Generated text: hi को रোধ کرنے میں آسانی پیدا ہوگی۔
# Enter your prompt (or 'exit' to quit): bye
# Generated text: bye, I'm going to have to disagree with you on this one. I don't think it's fair to say that the only way to be a good parent is to let your kids do whatever they want to do. There are times when you need to set limits and make sure that your child is following the rules and behaving in a way that is appropriate for their age and
# Enter your prompt (or 'exit' to quit): exit
